# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from tensorflow import layers
from tensorflow import keras
from sklearn.compose import make_column_transformer,make_column_selector
# Out:
#   Cell In[22], line 6
#     from tensorflow import keras.layers
#                                 ^
# SyntaxError: invalid syntax

# %%
df=pd.read_csv("original.csv")

# %%
prcessor=make_column_tranfor
# Out:
#           Gender        Age  POLAR4 Quintile  POLAR3 Quintile  \
# count  80.000000  80.000000        80.000000        80.000000
# mean    0.125000  22.212500         3.575000         3.287500
# std     0.332805   4.451408         1.438837         1.433715
# min     0.000000  19.000000         1.000000         1.000000
# 25%     0.000000  20.000000         2.000000         2.000000
# 50%     0.000000  21.000000         4.000000         4.000000
# 75%     0.000000  22.000000         5.000000         4.250000
# max     1.000000  44.000000         5.000000         5.000000
#
#        Adult HE 2001 Quintile  Adult HE 2011 Quintile  TUNDRA MSOA Quintile  \
# count               80.000000               80.000000             80.000000
# mean                 2.712500                3.275000              2.850000
# std                  1.203305                1.395971              1.293606
# min                  1.000000                0.000000              0.000000
# ...

# %%
#reviews.country[0] this property is used to access a single cell where the 

#The reviews is the data ,country us the column name and 
#[0] is the row

# %% [markdown]
# In pandas ways you can select is by using the loc and iloc they work in to paradigm .loc is text based while i loc is numerical based
#
# To select the first row it can be reviews.iloc[0]
#
# The nature reviews.iloc[:3,0] means it takes the first three rows and then takes the first column.
#
# reviews.iloc[1:3,0] means it takes the second and forth row then takes the first column
#
# reviews.iloc[[1,2,4],0] this takes the second f,third and fifth row of the first column
#
# reviews.iloc[-5:] takes the last 5 rows and takes the whole column
#
#
# reviews.loc[reviews.country.isin(["italy","France"])]

# %% [markdown]
# Deep learning
# from tensorflow import keras
# from tensorflow import layers
#
# model=keras.Sequential([
#   layers.Dense(units=1,input_shape=[3])
# ])

# %% [markdown]
# from tensorflow import keras
# from tensorflow.keras import layers
#
#
# model=keras.Sequential([layers.Dense(units=3,shape_input=[3],activation="relu),layers.Dense(units=2,activation="relu),layers.Dense(unit=1)])

# %% [markdown]
# When training a model there are things you must put in place ,which include the loss function(Tells the model the difference between the actual value to the predicted value ), while the optimizer shows how to change the parameters based on the updated loss
#
# Initialization of the model is
#  model.compile(
#   optimier="adam",loss="mae"
# )
#
# Training the model based on the dataset is

# %%
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.compose import make_tranform_column,make_select_column

preprocessor=make_transform_column(
  (StandardScaler(),dtype_include=np.numner),
  (OneHotEncoder(sparse=False),make_select_column(dtype_include=object))
)
